# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#定制" data-toc-modified-id="定制-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>定制</a></span></li><li><span><a href="#插入数学公式" data-toc-modified-id="插入数学公式-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>插入数学公式</a></span></li><li><span><a href="#图片" data-toc-modified-id="图片-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>图片</a></span></li><li><span><a href="#表格" data-toc-modified-id="表格-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>表格</a></span></li><li><span><a href="#列表" data-toc-modified-id="列表-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>列表</a></span></li><li><span><a href="#执行代码" data-toc-modified-id="执行代码-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>执行代码</a></span></li><li><span><a href="#PDF-Export" data-toc-modified-id="PDF-Export-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>PDF Export</a></span></li><li><span><a href="#播放" data-toc-modified-id="播放-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>播放</a></span></li><li><span><a href="#插入-iframe" data-toc-modified-id="插入-iframe-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>插入 iframe</a></span></li></ul></div>

# %% [markdown]
# # <center><font color="#191970">用Jupyter Notebook 制作PPT</font></center>
# <br/>
#
# <center><img src=" python_basics/figs/uestclogo.jpg " width="13%"></center>
#
#  <center> <font color="#FFA500">李小飞</font> <font color="#191970">@ 电子科技大学 $\cdot$ 光电学院</font></center>

# %% [markdown]
# ## 定制
#
#
# Here's a list of things that can be customized.

# %% [markdown]
# ### <font color="#FFA500"> Choosing a theme </font>
#
# You can configure the `theme` of your presentation (which controls the
# general look and feel of the presentation) with:
#
#     {
#      ...
#      "rise": {"theme": "sky"}
#     }
#
# A few different themes included: `black`，`white`, `league`, `beige`, `sky`, `night`, `serif`, `simple`,	`solarized`, `blood`, `moon`

# %% [markdown]
# ### <font color="#FFA500"> Choosing a transition </font>
#
# The transition configuration defines what happens in between slides:
#
#     {
#      ...
#      "rise": {"transition": "zoom"}
#     }
#
#  Transition styles: `fade`,`slide`,`convex`, `concave`, `zoom`

# %% [markdown]
# ###   <font color="#FFA500"> Automatically launch RISE  </font>
#
# You can setup your notebook to start immediately with the slideshow
# view using the `autolaunch` config option. This typically is very
# helpful if you plan on publishing slideshows through something like
# `mybinder.org`:
#
#
#     {
#      ...
#      "rise": {"autolaunch": true}
#     }

# %% [markdown]
# ###  <font color="#FFA500"> header, footer and backimage  </font>
#
# As a more limited, but often more convenient alternative, you can
# define any of the following 3 settings.
#
# In this case, minimal styling is applied (floor and ceiling), but user
# is still responsible for cosmetic styling:
#
#     {
#      ...
#      "rise": {
#          "backimage": "mybackimage.png",
#          "header": "<h1>Hello</h1>",
#          "footer": "<h3>World!</h3>"
#      }
#     }

# %% [markdown]
# ###   <font color="#FFA500"> Enable a right scroll bar </font>
#
# To enable a right scroll bar when your content exceeds the slide vertical height,
# use the following configuration:
#
#     {
#      ...
#      "rise": {"scroll": true}
#     }

# %% [markdown]
# ###  <font color="#FFA500"> Enable chalkboard capabilities </font>
#
# Starting RISE 5.4.1, we provide some new chalkboard capabilities.
# To enable them, use the following configuration:
#
#     {
#      ...
#      "rise": {"enable_chalkboard": true}
#     }
#
# It also reacts to the following additional keyboard commands:
# * `[` to turn the whole space into an empty chalkboard
# * `]` to start adding free drawings to the current slide
# * `\` to download chalkboard drawing
# * `=` to reset chalkboard drawing on the current slide
# * `-` to clear the chalkboard

# %% [markdown]
# ###  <font color="#FFA500"> Notebook metadata </font>
#
# These settings can also be stored in your notebook metadata, which
# holds a JSON object, that can be edited through Jupyter's standard
# menu (Edit → Edit Notebook Metadata); typically it would look like
# this:
#
#     {
#         ...
#         "rise": {
#             "theme": "serif",
#             "transition": "zoom",
#             ...
#         },
#         ...
#     }
# You can edit notebook metadata as follows
#
# ![](../examples/metadata.png)

# %% [markdown]
# ###   <font color="#FFA500"> Keyboard shortcuts and Jupyter actions </font>
#
# Here are the Jupyter actions registered by RISE:
#
#     action name                key      behaviour
#     ------------------------------------------------------
#     RISE:slideshow            alt-r  enter/exit RISE Slideshow

# %% [markdown]
# ###  <font color="#FFA500"> Native keyboard shortcuts for reveal.js and reveal.js plug-ins </font>
#
# Some custom keyboard shortcuts may be defined in RISE to override the default
# keyboard shortcuts of `reveal.js` and/or its plug-ins.
#
# The key bindings can be defined via the `nbextensions_configurator` or directly
# in JSON.
#
# The table below shows the avaialble key bindings:
#
# 	module      action               default key  behaviour
#     ---------------------------------------------------------
#     main        firstSlide           home         jump to first slide
#     main        lastSlide            end          jump to last slide
#     main        toggleOverview       w            toggles slide overview
#     main        fullscreenHelp       f            show fullscreen help
#     main        riseHelp             ?            show the RISE help
#     chalkboard  clear                -            clear full size chalkboard
#     chalkboard  reset                =            reset chalkboard data on current slide
#     chalkboard  toggleChalkboard     [            toggle full size chalkboard
#     chalkboard  toggleNotesCanvas    ]            toggle notes (slide-local)
#     chalkboard  download             \            download recorded chalkboard drawing

# %% [markdown]
# ## 插入数学公式

# %% [markdown]
# - 行内公式 $\begin{aligned}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{aligned} $
#
# -

# %% [markdown]
# - 行间公式
#
# $$\begin{aligned}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{aligned} $$

# %% [markdown]
# - 复杂公式
# $$         \begin{equation*}
#             \begin{split}
#                 \Psi(\vec{r},t)&=\sum_n a_n(t) u_n(\vec{r}) \\
#                 &=a_1(t) u_1+ a_2(t) u_2+\cdots+ a_n(t) u_n \\
#                 &=(u_1,u_2,\cdots,u_n)
#                \begin{pmatrix}
#                     a_1(t)\\
#                     a_2(t)\\
#                     \cdots\\
#                     a_n(t)
#                 \end{pmatrix} \\
#                 &= (u_1,u_2,\cdots,u_n) (a_1(t),a_2(t),\cdots, a_n(t))^T
#             \end{split}
#         \end{equation*}  $$

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
\nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
\nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
\nabla \cdot \vec{\mathbf{B}} & = 0 
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %% [markdown]
# ## 图片

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt  # 用于画图
import matplotlib.image as mpimg  # 用于显示图片

cat = mpimg.imread('python_basics/figs/uestclogo.jpg')
# print(cat)
plt.imshow(cat)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ```
# ![图片](python_basics/figs/uestclogo.jpg)
# ```
#
# ![图片](python_basics/figs/uestclogo.jpg)

# %% [markdown]
# <center><img src=" figs/uestclogo.jpg " width="5%"></center>

# %% [markdown]
# ## 表格
#
# prior to 5.6 we were getting very small tables
#
#
# | sample | table |
# |--------|-------|
# | men    | 10%   |
# | women  | 70%   |
# | children | 30% |

# %% [markdown]
# ## 列表
#
# * the text for the slide
# * and so on
# * and on

# %% [markdown]
# * that's typically the slide we'd like to skip
# * 2 options for the meaning ok 'skip'
#   1. need to mark all 3 cells in the slide as 'skip'
#   1. mark the 'slide 2' cell as 'skip', and that's enough

# %% [markdown]
# * here the items
#
# * are separated with
#
# * one blank line
#
# * between each pair of consecutive lines

# %% [markdown]
# * here the items
# </br>
# </br>
# * are separated with
# </br>
# </br>
# * **2 blank lines**
# </br>
# </br>
# * between each pair of consecutive lines

# %% [markdown]
# ## 执行代码

# %%
# Let's define a function (this cell can be hidden from the slideshow if you like)

# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

def plot_graph(a=-0.1,b=0.8,c=-0.3):
    # some arbitrary function of a,b,c
    x = np.linspace(0,10,100)
    y = a*a*np.square(x) + (b+a)*np.sin(x) + (c-a)*np.cos(x) + c*x
    plt.plot(x,y)
    plt.ylim(-20,30)
    plt.show()

# %%
# Here's a static evaluation with default args
plot_graph(1.2,0.121,2.5)

# %%
interact(plot_graph, a=(-2,2,0.2), b=(-2,3,0.1), c=(-2,2,0.1));

# %% [markdown]
# ## PDF Export
#
# You can export your RISE presentation to PDF using the following procedures:
#
# 1. Generate the slides and serve them using nbconvert:
#
#     `jupyter nbconvert --to slides your_talk.ipynb --post serve`
#
#     It opens up a webpage in the browser at http://127.0.0.1:8000/your_talk.slides.html#/
#
# 1. Add ``?print-pdf`` to the query string as http://127.0.0.1:8000/your_talk.slides.html?print-pdf
#
#     Note that you need to remove the ``#`` at the end. The page will render the slides vertically.
#
# 1. Save to PDF in Chrome using the print option
#
#   + Open the in-browser print dialog (Cmd/Ctrl + P).
#   + Change the Destination setting to Save as PDF.
#   + Change the Layout to Landscape.
#   + Change the Margins to None.
#   + Enable the Background graphics option.
#   + Click Save.
#
# The last step can also be done from the command line:
#
# `google-chrome --headless --print-to-pdf=your_talk.pdf http://127.0.0.1:8000/your_talk.slides.html?print-pdf`

# %% [markdown]
# ## 播放
#
# 1. 空格/推进， shift+空格/后退， shift+回车/执行代码
#
# 1. 左/划重点，右/删除划线, q(s)/变色
#
# 1. -/clear full size chalkboard， =/reset chalkboard data on current slide
#
# 1. command+"+"/放大， command+"-"/缩小
#
# 1. 浏览器 Chrome+全屏+不显示工具栏

# %% [markdown]
# ## 插入 iframe

# %%
from IPython.display import IFrame
IFrame('https://arxiv.org/pdf/1406.2661.pdf', width=800, height=450)

# %%
IFrame('https://www.uestc.edu.cn/', width=800, height=450)

# %%
# %lsmagic

# %%
# %time a = range(10)
